# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import RandomizedSearchCV, cross_val_score

# %%
whitewine = pd.read_csv('data/winequality-white.csv', delimiter=';')

# %%
whitewine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
bins = [0, 5.5, 7.5, 10]
labels = [0, 1, 2]
whitewine['quality'] = pd.cut(whitewine['quality'], bins=bins, labels=labels)

# %%
X = whitewine.drop("quality",axis=1)

y = whitewine["quality"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3428, 11), (1470, 11), (3428,), (1470,))

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=30, min_samples_split=4, n_estimators=200)

# %%
y_preds = clf.predict(X_test)

# %%
clf.score(X_train,y_train)
# Out:
# 0.9979579929988331

# %%
clf.score(X_test,y_test)
# Out:
# 0.8170068027210884

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
accuracy_score(y_test,y_preds)
# Out:
# 0.8170068027210884

# %%
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73       491
#            1       0.81      0.91      0.86       924
#            2       0.94      0.31      0.47        55
#
#     accuracy                           0.81      1470
#    macro avg       0.85      0.63      0.69      1470
# weighted avg       0.81      0.81      0.80      1470

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV

# %%
grid = {"n_estimators":[100,200,500],
       "max_depth": [20,30],
       "max_features": ["auto","sqrt"],
       "min_samples_split": [2,4,6],
       "min_samples_leaf":[1,2,4]}

# %%
np.random.seed(42)
clf =RandomForestClassifier(n_jobs=1)
rs_clf = RandomizedSearchCV(estimator=clf,
                       param_distributions=grid,
                       n_iter=10,
                       cv=5,verbose=2)
rs_clf.fit(X_train,y_train)
rs_clf.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20, total=   6.0s
# [CV] n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.9s remaining:    0.0s
# [CV]  n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20, total=   6.0s
# [CV] n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20, total=   5.7s
# [CV] n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20, total=   5.7s
# [CV] n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=20, total=   5.7s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None, total=   1.0s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None, total=   1.0s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None, total=   0.9s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None, total=   1.1s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=4, max_features=auto, max_depth=None, total=   1.0s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30, total=   0.0s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=30, total=   0.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.0s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.0s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=30, total=   1.0s
# [CV] n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   0.6s
# [CV] n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   0.6s
# [CV] n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   0.6s
# [CV] n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   0.5s
# [CV] n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=100, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   0.6s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   1.2s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   1.2s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, total=   1.2s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=None, total=   0.1s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.1s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.1s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.1s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.1s
# [CV] n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None
# [CV]  n_estimators=200, min_samples_split=6, min_samples_leaf=1, max_features=sqrt, max_depth=None, total=   1.1s
# [CV] n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   5.1s
# [CV] n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   5.2s
# [CV] n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   5.1s
# [CV] n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   5.1s
# [CV] n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=4, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   5.2s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10, total=   5.1s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10, total=   5.0s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10, total=   5.1s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10, total=   4.9s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=4, max_features=auto, max_depth=10, total=   4.9s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.7min finished
# {'n_estimators': 200,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 30}

# %%
np.random.seed(42)
clf =RandomForestClassifier(n_jobs=1)
rs_clf = GridSearchCV(estimator=clf,
                       param_grid=grid,
                    
                       cv=5,verbose=2)
rs_clf.fit(X_train,y_train)
rs_clf.best_params_
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.8s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.2s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.2s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.2s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.8s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.2s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.8s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.4s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.4s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.3s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.1s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.2s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.7s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.6s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# ...
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.6s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=6, n_estimators=500, total=   2.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=500, total=   2.4s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=100, total=   0.5s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   1.0s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=200, total=   0.9s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.3s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.4s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.4s
# [CV] max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500
# [CV]  max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=500, total=   2.3s
# [Parallel(n_jobs=1)]: Done 540 out of 540 | elapsed: 12.3min finished
# {'max_depth': 30,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 200}

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth= 30,
 max_features="auto",
 min_samples_leaf=1,
 min_samples_split=4,
 n_estimators= 200)
